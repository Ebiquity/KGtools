# %%
from utilities import ask

# %% [markdown]
# An example showing how to query wikidata for information on malware instances.  For wikidata, we need to know the special identifiers it uses for types (e.g., wd:Q14001 is 'malware') and properties (e.g., wdt:P31 is 'is-a') an we also typically filter to select strings in a desired language (e.g., english or 'en').

# %%
endpoint = "https://query.wikidata.org/sparql"

# %% [markdown]
# We can comment out the prefixes since the wikidata query service has these and many others pre-defined.  This query uses a group by so that we can gather up all of the values of operating system (?ops) into a single string.

# %%
query = """
# find instances (direct or inderect) of malware and their ID, name,
# description, aliases, and operating systems
# PREFIX wdt: <http://www.wikidata.org/prop/direct/>
# PREFIX wd: <http://www.wikidata.org/entity/>
select ?m ?mLabel ?mDescription ?mAltLabel
       (GROUP_CONCAT(?ops;SEPARATOR=",") AS ?os) 
where {
  # ?m wdt:P31/wdt:P279* wd:Q14001.
  OPTIONAL { ?m wdt:P306/rdfs:label ?ops . 
             FILTER(lang(?ops) = "" || LANG(?ops) = "en")
           }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
} 
group by ?m ?mLabel ?mDescription ?mAltLabel"""

# %% [markdown]
# our simple ask function returns a stream of tuples where each tuple has the values from one result

# %%
for tuple in ask(endpoint, query):
    print(tuple)
# Out:
# ('http://www.wikidata.org/entity/Q158593', 'Brain', 'computer virus', '(c)Brain', '')
# ('http://www.wikidata.org/entity/Q256995', 'Kenzero', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q474330', 'Conficker', 'computer worm', 'Kido, Downadup, Downup', '')
# ('http://www.wikidata.org/entity/Q523220', 'Stoned', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q590243', 'Melissa', 'mass-mailing macro virus', 'W97M.Melissa.A', '')
# ('http://www.wikidata.org/entity/Q607338', 'Michelangelo', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q798333', 'Back Orifice', 'computer program designed for remote system administration', 'BO', '')
# ('http://www.wikidata.org/entity/Q941302', 'Mac Defender', 'rogue security software', '')
# ('http://www.wikidata.org/entity/Q1023724', 'CIH', 'Microsoft Windows computer virus', 'Chernobyl, Spacefiller', '')
# ('http://www.wikidata.org/entity/Q1066619', 'Flame', 'modular computer malware', 'Flamer, Da Flame, sKyWIper, Skywiper', '')
# ('http://www.wikidata.org/entity/Q1185966', 'Ambulance', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q1246473', 'Cascade', 'resident computer virus', '')
# ('http://www.wikidata.org/entity/Q1331418', 'Elk Cloner', 'microcomputer virus', '')
# ('http://www.wikidata.org/entity/Q1437357', 'Form', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q1454900', 'Sasser', 'computer worm', '')
# ('http://www.wikidata.org/entity/Q1687955', 'Jerusalem', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q2052454', 'Q2052454', '')
# ('http://www.wikidata.org/entity/Q2073163', 'Gumblar', 'malware for Windows', '')
# ('http://www.wikidata.org/entity/Q2124587', 'RST.b', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q2148637', 'Kampana virus', 'a boot sector virus infecting the DOS boot sector of floppy disks and Master Boot Record of the first hard drive', '')
# ('http://www.wikidata.org/entity/Q2626364', 'Cabir', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q2710876', 'rkhunter', 'Unix-based tool that scans for rootkits, backdoors and possible local exploits', 'Rootkit Hunter', '')
# ('http://www.wikidata.org/entity/Q2791342', 'Online surveillance (Germany)', '')
# ('http://www.wikidata.org/entity/Q3231604', '3wPlayer', '')
# ('http://www.wikidata.org/entity/Q3241245', 'SpySheriff', 'spyware', '')
# ('http://www.wikidata.org/entity/Q3277669', 'Mahdi', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q3297439', 'Ada', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q3299019', 'Acid', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q3496143', 'Anna Kournikova computer worm', 'computer worm', 'VBS/SST-A', '')
# ('http://www.wikidata.org/entity/Q3507450', 'Eliza', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q3540223', 'Q3540223', '')
# ('http://www.wikidata.org/entity/Q3700498', 'DNSChanger', 'computer malware', '')
# ('http://www.wikidata.org/entity/Q3915260', 'Zeus', 'computer Trojan horse', '')
# ('http://www.wikidata.org/entity/Q3982407', 'Techno', 'computer virus', 'Techno Virus', '')
# ('http://www.wikidata.org/entity/Q4046974', 'Pinch', 'Trojan', 'LdPinch', '')
# ('http://www.wikidata.org/entity/Q4548469', '1260', '')
# ('http://www.wikidata.org/entity/Q4638927', '4K', 'computer virus which infects COM files and EXE files', '')
# ('http://www.wikidata.org/entity/Q4652022', 'AI', '')
# ('http://www.wikidata.org/entity/Q4669447', 'Abraxas', '')
# ('http://www.wikidata.org/entity/Q4674386', 'Acme', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q4676824', 'Actifed', '')
# ('http://www.wikidata.org/entity/Q4691979', 'Agena', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q4700504', 'Akbot', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q4705176', 'Alabama', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q4713382', 'Alcra', 'computer worm', 'W32.Alcra. F', '')
# ('http://www.wikidata.org/entity/Q4774499', 'AntiCMOS', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q4839599', 'Backdoor Shell', 'web security threat that enables remote access to a web server', 'Web shell', '')
# ('http://www.wikidata.org/entity/Q4840653', 'Badbunny', 'multi-platform computer worm', 'SB/BadBunny-A, StarOffice/BadBunny', '')
# ('http://www.wikidata.org/entity/Q4923008', 'Blackhole exploit kit', '')
# ('http://www.wikidata.org/entity/Q4940618', 'Bomber', '')
# ('http://www.wikidata.org/entity/Q5014646', 'CTX', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q5048840', 'Casino', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q5125464', 'Clampi', 'man-in-the-browser trojan', 'Ilomo, Ligats', '')
# ('http://www.wikidata.org/entity/Q5170233', 'Coreflood', 'Coreflood botnet', '')
# ('http://www.wikidata.org/entity/Q5268371', 'Dexter', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q5289198', 'DollarRevenue', 'adware program', '')
# ('http://www.wikidata.org/entity/Q5370288', 'Emcodec', '')
# ('http://www.wikidata.org/entity/Q5445669', 'Festering Hate', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q5508622', 'Fun.exe virus', '')
# ('http://www.wikidata.org/entity/Q5551280', 'Motaba', 'malware', '')
# ('http://www.wikidata.org/entity/Q5559882', 'Gifar', '')
# ('http://www.wikidata.org/entity/Q5598292', 'Graybird', '')
# ('http://www.wikidata.org/entity/Q5953387', 'Hybris', 'computer worm', 'Snow White, Full Moon, Vecna.22528', '')
# ('http://www.wikidata.org/entity/Q6012283', 'Spyaxe', 'Adware', '')
# ('http://www.wikidata.org/entity/Q6079605', 'Isearch', '')
# ('http://www.wikidata.org/entity/Q6647393', 'UltimateCleaner', 'malware software', '')
# ('http://www.wikidata.org/entity/Q6660355', 'LizaMoon', 'malware', '')
# ('http://www.wikidata.org/entity/Q6715135', 'MDEF', 'computer virus', 'Top Cat, Garfield', '')
# ('http://www.wikidata.org/entity/Q6722021', 'MacGag', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q6745153', 'Malware Bell', '')
# ('http://www.wikidata.org/entity/Q7094588', 'Ontario', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q7389090', 'SCA', 'first computer virus for Commodore Amiga', '')
# ('http://www.wikidata.org/entity/Q7435329', 'Scores', 'computer virus affecting Macintosh computers', '')
# ('http://www.wikidata.org/entity/Q7435830', "Scott's Valley", 'computer virus', '')
# ('http://www.wikidata.org/entity/Q7444994', 'Security Shield', '')
# ('http://www.wikidata.org/entity/Q7487621', 'Shamoon', 'modular computer virus', 'Disttrack', '')
# ('http://www.wikidata.org/entity/Q7488666', "Shankar's Virus", '')
# ('http://www.wikidata.org/entity/Q7517814', 'Simile', '')
# ('http://www.wikidata.org/entity/Q7639318', 'Sunday', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q7989860', 'Westwood', '')
# ('http://www.wikidata.org/entity/Q7990487', 'Whale', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q8073103', 'Zmist', '')
# ('http://www.wikidata.org/entity/Q10394244', 'Xandu.2385', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q10744176', 'Cansu', 'boot sector virus', '')
# ('http://www.wikidata.org/entity/Q10750653', 'Cossiga', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q10852219', 'QQ tail', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q11190348', 'Antinny', '')
# ('http://www.wikidata.org/entity/Q11194852', 'Concept', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q12057271', 'Susenka', 'computer virus', 'Dejmi', '')
# ('http://www.wikidata.org/entity/Q12626556', 'Adolph', 'computer virus', 'Adolf Hitler', '')
# ('http://www.wikidata.org/entity/Q12644278', 'V.302', '')
# ('http://www.wikidata.org/entity/Q13729412', 'Q13729412', '')
# ('http://www.wikidata.org/entity/Q16110244', 'ANTI', '')
# ('http://www.wikidata.org/entity/Q16163381', '2090 virus', 'computer virus', 'V.WOM.Aimbot.CC, Win32/AimBot.worm.15872', '')
# ('http://www.wikidata.org/entity/Q16919284', 'Brave Sentry', '')
# ('http://www.wikidata.org/entity/Q16978760', 'Ghostball', '')
# ('http://www.wikidata.org/entity/Q16979355', 'Careto', '')
# ('http://www.wikidata.org/entity/Q17037729', 'Strange Brew', 'first computer virus that infects java code', '')
# ('http://www.wikidata.org/entity/Q54958832', 'Jingwang Weishi', 'mobile app spyware that Chinese police forces some citizens to install', 'Jìngwǎng Wèishì', 'Android')
# ('http://www.wikidata.org/entity/Q4713809', 'Aldiko', 'Android,iOS')
# ('http://www.wikidata.org/entity/Q22669996', 'Linux.Encoder.1', 'considered the first ransomware Trojan targeting computers running Linux', 'ELF/Filecoder.A, Trojan.Linux.Ransom.A', 'Linux,Linux')
# ('http://www.wikidata.org/entity/Q22937461', 'Linux.Wifatch', 'malware that secures infected devices', 'Reincarna, Zollard', 'Linux')
# ('http://www.wikidata.org/entity/Q27517815', 'Mirai', 'malware that turns computer systems running Linux into remotely controlled "bots"', 'Mira Malware', 'Linux,embedded Linux distribution')
# ('http://www.wikidata.org/entity/Q27942637', 'Linux.Darlloz', 'computer worm for Linux IoT devices', 'CVE-2012-1823', 'Linux')
# ('http://www.wikidata.org/entity/Q28135507', 'BASHLITE', 'malware for Linux systems', 'Bashdoor, Gafgyt, LizardStresser, Lizkebab, Qbot, Torlus', 'Linux')
# ('http://www.wikidata.org/entity/Q28324926', 'Remaiten', 'malware for embedded Linux systems', 'Linux,embedded Linux distribution')
# ('http://www.wikidata.org/entity/Q67923329', 'Audiogalaxy Satellite', 'popular historic peer-to-peer file sharing software', 'AG Satellite, AGent', 'Linux,Microsoft Windows')
# ('http://www.wikidata.org/entity/Q127101', 'Staog', 'Linux')
# ('http://www.wikidata.org/entity/Q1279926', 'Lupper', 'computer worm', 'Lupper.worm.b,', 'Linux')
# ('http://www.wikidata.org/entity/Q590719', 'Stars virus', 'computer virus', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q1050751', 'Sub7', 'remote administration tool/trojan', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q1724649', 'Extended Copy Protection', 'copy protection rootkit by Sony BMG', 'Sony rootkit, XCP rootkit', 'Microsoft Windows,Microsoft Windows')
# ('http://www.wikidata.org/entity/Q3926208', 'QH.EXE', 'malware', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q6947728', 'W32.MyLife@mm', 'computer worm', 'MyLife, W32/Mylife, W32/MyLife-A, W32/MyLife.a@MM, Win32.MyLife.A, WORM_MYLIFE.A', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q10852162', 'Pinfi', 'Windows virus', 'W32.Pinfi', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q6955695', 'nVIR', 'obsolete computer virus', 'Mac OS')
# ('http://www.wikidata.org/entity/Q7457150', 'SevenDust', 'Mac OS computer virus', 'Mac OS')
# ('http://www.wikidata.org/entity/Q15122248', 'CryptoLocker', 'malware', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q18572753', 'Regin', 'sophisticated malware', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q19605783', 'TeslaCrypt', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q21753918', 'Sykipot', 'computer malware', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q23670513', 'Petya', 'a family of encrypting ransomware discovered in 2016', 'GoldenEye, NotPetya, Petya.2017', 'Microsoft Windows,Microsoft Windows')
# ('http://www.wikidata.org/entity/Q25110410', 'CryptMix', 'ransomware', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q26260309', 'ProjectSauron', 'Spyware, probably created by a country to spy some other countries national agencies', 'Project Sauron, Remsec', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q42326624', 'Bad Rabbit', 'Microsoft Windows,Microsoft Windows')
# ('http://www.wikidata.org/entity/Q48734883', 'Hitler-Ransomware', 'ransomware', 'Hitler-Ransonware', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q55615073', 'Jigsaw', 'ransomware', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q60525697', 'RedEye Ransomware', 'Red Eye program, RedEye, RedEye criminal', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q83375918', 'Rensenware', 'ransomware', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q83982303', 'Kirk Ransomware', 'Ransomware malware originated in 2017', 'Microsoft Windows')
# ('http://www.wikidata.org/entity/Q884438', 'Bliss', 'Linux computer virus', 'Unix-like')
# ('http://www.wikidata.org/entity/Q4353528', 'AIDS', 'ransomware trojan', 'Cyborg, Aids Info Disk, AIDS Trojan, AIDS!Trojan, Aidsinfo. A trojan, Aidsinfo. B trojan, Love virus, PC Cyborg Trojan, Trj/AidsInfo. A, Trj/AidsInfo. B, Trojaids!Trojan, Trojan. AidsInfo.a, Trojan. AidsInfo.b', 'MS-DOS,MS-DOS')
# ('http://www.wikidata.org/entity/Q856096', 'ILOVEYOU', 'computer worm', 'I love you, I Love You, Love Letter, Loveletter', 'Windows 2000,Windows NT,Windows 9x')
# ('http://www.wikidata.org/entity/Q1139499', 'Creeper', 'computer worm', 'TOPS-20')
# ('http://www.wikidata.org/entity/Q29908721', 'WannaCry', 'Ransomware', 'Ransom.Win32.Wannacry, WanaCrypt0r 2.0, Wanna Decryptor, WannaCrypt, WCry', 'Windows 7,Windows Server 2008,Windows XP,Windows 10,Windows 8.1')
# ('http://www.wikidata.org/entity/Q15734339', 'Esperanto', 'computer virus', 'Mac OS,MS-DOS,Windows 95,Windows NT 4.0,Windows NT 3.x')
# ('http://www.wikidata.org/entity/Q16911416', 'Fakeflash', 'Trojan.FakeFlash.A', 'macOS')
# ('http://www.wikidata.org/entity/Q23303160', 'KeRanger', 'ransomware', 'macOS')
# ('http://www.wikidata.org/entity/Q22920668', 'Locky', 'ransomware program', 'Windows 8')
# ('http://www.wikidata.org/entity/Q22080723', 'KeyRaider', 'iOS')
# ('http://www.wikidata.org/entity/Q26734737', 'Pegasus (spyware)', 'malware', 'Pegasus', 'iOS,iOS')
# ('http://www.wikidata.org/entity/Q66493916', 'Syslock', 'strain of computer virus', 'DOS')
# ('http://www.wikidata.org/entity/Q17621210', 'MadMan', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q18204794', 'Gameover ZeuS', 'peer-to-peer botnet', '')
# ('http://www.wikidata.org/entity/Q19888780', 'Rombertik', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q20647186', 'Duqu 2.0', '')
# ('http://www.wikidata.org/entity/Q21043310', 'Backdoor.Win32.Hupigon', 'backdoor Trojan first detected in November, 2008', 'Backdoor.Win32.Graftor', '')
# ('http://www.wikidata.org/entity/Q22050551', 'BlackEnergy', '')
# ('http://www.wikidata.org/entity/Q22908430', 'Sad Satan', 'computer game', '')
# ('http://www.wikidata.org/entity/Q22909790', 'Wirelurker', 'Computer virus', '')
# ('http://www.wikidata.org/entity/Q24896672', 'Point-of-sale malware', 'Malicious software that is used by cybercriminals to target point of sale and payment terminals with the intent to obtain credit card and debit card information  by various man-in-the-middle attacks.', 'POS malware', '')
# ('http://www.wikidata.org/entity/Q24965511', 'TorrentLocker', '')
# ('http://www.wikidata.org/entity/Q25413775', 'Amoeba', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q25496775', 'SoakSoak', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q25619410', 'AIDS II', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q27628005', 'CenterPOS Malware', 'CenterPOS has been used to target retailers in order to illegally obtain payment card information using a memory scraper', 'Cerebrus', '')
# ('http://www.wikidata.org/entity/Q28451215', 'KoKo', '')
# ('http://www.wikidata.org/entity/Q28451554', 'X Agent', '')
# ('http://www.wikidata.org/entity/Q28779495', 'Q28779495', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q30249562', 'EternalRocks worm', 'EternalRocks, MicroBotMassiveNet', '')
# ('http://www.wikidata.org/entity/Q30592329', 'LogicLocker', 'ransomware that affects PLCs', '')
# ('http://www.wikidata.org/entity/Q30688185', 'Emotet', '')
# ('http://www.wikidata.org/entity/Q30894144', 'Bubbleboy', '')
# ('http://www.wikidata.org/entity/Q31842581', 'Q31842581', '')
# ('http://www.wikidata.org/entity/Q34796452', 'Kronos', 'form of trojan or malware', '')
# ('http://www.wikidata.org/entity/Q40888611', 'Xafecopy Trojan', '')
# ('http://www.wikidata.org/entity/Q40889952', 'Industroyer', 'malware framework considered to have been used in the cyberattack on Ukraine’s power grid on December 17, 2016', 'Crashoverride', '')
# ('http://www.wikidata.org/entity/Q42793574', 'Bugbear', '')
# ('http://www.wikidata.org/entity/Q47501879', 'Jaff', 'computer virus', '')
# ('http://www.wikidata.org/entity/Q54143881', 'VPNFilter', 'malware', '')
# ('http://www.wikidata.org/entity/Q56885850', 'Q56885850', '')
# ('http://www.wikidata.org/entity/Q60740739', 'BrickerBot', 'malware targeting IoT devices', '')
# ('http://www.wikidata.org/entity/Q60764510', 'MEMZ trojan', 'Computer virus', '')
# ('http://www.wikidata.org/entity/Q60768340', 'FBI MoneyPak Ransomware', 'ransomware', '')
# ('http://www.wikidata.org/entity/Q63646250', 'b374k', 'The b374k shell is a PHP malware.', 'b374k, B374K', '')
# ('http://www.wikidata.org/entity/Q64870676', 'Ryuk', 'ransomware', '')
# ('http://www.wikidata.org/entity/Q65081561', 'China Chopper', 'web shell', '')
# ('http://www.wikidata.org/entity/Q65280176', 'Triton', 'malware', '')
# ('http://www.wikidata.org/entity/Q66475728', 'Trojan.PSPBrick', 'trojan horse for the PlayStation Portable', '')
# ('http://www.wikidata.org/entity/Q73228433', 'Web shell', 'A web shell is a web security threat that is a web-based implementation of the shell concept.', 'Backdoor, PHP web shell, Web based backdoor', '')
# ('http://www.wikidata.org/entity/Q83497471', 'Galileo', 'spyware', '')
# ('http://www.wikidata.org/entity/Q90799138', 'Raadioga.1000', '')
# ('http://www.wikidata.org/entity/Q95135524', 'Q95135524', '')
# ('http://www.wikidata.org/entity/Q96165476', 'Q96165476', 'boot sector virus', '')
# ('http://www.wikidata.org/entity/Q53479', 'Stuxnet', 'computer worm, discovered in June 2010', 'RootkitTmphider, W32.Stuxnet, W32.Temphid', '')
